# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_description = city_weather["weather"][0]["description"]  
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description,
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gornopravdinsk
# Processing Record 2 of Set 1 | morro bay
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | lyngdal
# Processing Record 9 of Set 1 | mayor pablo lagerenza
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | buraydah
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | sahuaripa
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | soe
# Processing Record 17 of Set 1 | pacifica
# Processing Record 18 of Set 1 | merauke
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | hofn
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | betzdorf
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | isangel
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | meilu
# City not found. Skipping...
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | qui nhon
# Processing Record 34 of Set 1 | ryabovo
# Processing Record 35 of Set 1 | nehe
# Processing Record 36 of Set 1 | prince george
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | san javier
# Processing Record 40 of Set 1 | kuzedeyevo
# Processing Record 41 of Set 1 | tefe
# Processing Record 42 of Set 1 | adamas
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | pochutla
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | danjiangkou
# Processing Record 47 of Set 1 | popondetta
# Processing Record 48 of Set 1 | maloy
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | dunmore town
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | unye
# City not found. Skipping...
# Processing Record 6 of Set 2 | apac
# Processing Record 7 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | tura
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | chunoyar
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 2 | praya
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | dromolaxia
# Processing Record 21 of Set 2 | faya
# Processing Record 22 of Set 2 | cairns
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | ngunguru
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | itupiranga
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | urusha
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | capaci
# Processing Record 41 of Set 2 | flinders
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | zlynka
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | shihezi
# Processing Record 46 of Set 2 | russell
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | axim
# Processing Record 50 of Set 2 | sadowara
# City not found. Skipping...
# Processing Record 1 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | shimoda
# Processing Record 3 of Set 3 | olafsvik
# Processing Record 4 of Set 3 | souris
# Processing Record 5 of Set 3 | yerbogachen
# Processing Record 6 of Set 3 | balykshi
# Processing Record 7 of Set 3 | antalaha
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | diphu
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 3 | el roble
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | aksha
# Processing Record 17 of Set 3 | galle
# Processing Record 18 of Set 3 | isla vista
# Processing Record 19 of Set 3 | sonamura
# Processing Record 20 of Set 3 | buin
# Processing Record 21 of Set 3 | slavyanka
# Processing Record 22 of Set 3 | anloga
# Processing Record 23 of Set 3 | vydrino
# Processing Record 24 of Set 3 | ust-nera
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | pangai
# Processing Record 28 of Set 3 | wilmington
# Processing Record 29 of Set 3 | mahon
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | mishkino
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | cabedelo
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | saint peters
# Processing Record 45 of Set 3 | itoman
# Processing Record 46 of Set 3 | batagay-alyta
# Processing Record 47 of Set 3 | makakilo city
# Processing Record 48 of Set 3 | alyangula
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | jumla
# Processing Record 3 of Set 4 | kushmurun
# Processing Record 4 of Set 4 | boffa
# Processing Record 5 of Set 4 | grand-lahou
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | poya
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | ulladulla
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | dum duma
# Processing Record 13 of Set 4 | beloha
# Processing Record 14 of Set 4 | agbor
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | naze
# Processing Record 17 of Set 4 | lalibela
# Processing Record 18 of Set 4 | kharp
# Processing Record 19 of Set 4 | sidi ali
# Processing Record 20 of Set 4 | ikwiriri
# Processing Record 21 of Set 4 | abbeville
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 4 | beringovskiy
# Processing Record 26 of Set 4 | ornskoldsvik
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | coihaique
# Processing Record 29 of Set 4 | mantua
# Processing Record 30 of Set 4 | ocana
# Processing Record 31 of Set 4 | black river
# Processing Record 32 of Set 4 | portadown
# Processing Record 33 of Set 4 | inirida
# Processing Record 34 of Set 4 | tera
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | dese
# Processing Record 37 of Set 4 | saint george
# Processing Record 38 of Set 4 | ascension
# Processing Record 39 of Set 4 | manyana
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | shangrao
# Processing Record 44 of Set 4 | kloulklubed
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | smolensk
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 49 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 4 | dudinka
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | savannah bight
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | paducah
# Processing Record 7 of Set 5 | torbay
# Processing Record 8 of Set 5 | karratha
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | chapais
# Processing Record 11 of Set 5 | nefteyugansk
# Processing Record 12 of Set 5 | asyut
# Processing Record 13 of Set 5 | cocal
# Processing Record 14 of Set 5 | adrar
# Processing Record 15 of Set 5 | tulun
# Processing Record 16 of Set 5 | udachnyy
# Processing Record 17 of Set 5 | margate
# Processing Record 18 of Set 5 | san luis
# Processing Record 19 of Set 5 | natal
# Processing Record 20 of Set 5 | morlaix
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | atasu
# Processing Record 24 of Set 5 | krasnoturansk
# Processing Record 25 of Set 5 | beyneu
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | upata
# Processing Record 28 of Set 5 | nokaneng
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | ratnagiri
# Processing Record 31 of Set 5 | dali
# Processing Record 32 of Set 5 | paita
# Processing Record 33 of Set 5 | loubomo
# Processing Record 34 of Set 5 | vardo
# Processing Record 35 of Set 5 | waipawa
# Processing Record 36 of Set 5 | santa vitoria do palmar
# Processing Record 37 of Set 5 | sisimiut
# Processing Record 38 of Set 5 | heihe
# Processing Record 39 of Set 5 | byron bay
# Processing Record 40 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 5 | sinjai
# Processing Record 42 of Set 5 | hualmay
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | oktyabrskiy
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | lixourion
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | maceio
# Processing Record 50 of Set 5 | drayton valley
# Processing Record 1 of Set 6 | wucheng
# Processing Record 2 of Set 6 | mazyr
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | salinopolis
# Processing Record 5 of Set 6 | burica
# City not found. Skipping...
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | nome
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | valdivia
# Processing Record 11 of Set 6 | vadakku valliyur
# Processing Record 12 of Set 6 | mporokoso
# Processing Record 13 of Set 6 | abu samrah
# Processing Record 14 of Set 6 | ampanihy
# Processing Record 15 of Set 6 | makokou
# Processing Record 16 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 6 | kasungu
# Processing Record 18 of Set 6 | honningsvag
# Processing Record 19 of Set 6 | itarema
# Processing Record 20 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 6 | kalmunai
# Processing Record 22 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 6 | amahai
# Processing Record 24 of Set 6 | katobu
# Processing Record 25 of Set 6 | foumban
# Processing Record 26 of Set 6 | ilebo
# Processing Record 27 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 6 | santo augusto
# Processing Record 29 of Set 6 | thinadhoo
# Processing Record 30 of Set 6 | marshfield
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | prado
# Processing Record 33 of Set 6 | ajaccio
# Processing Record 34 of Set 6 | kupang
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 6 | manacapuru
# Processing Record 38 of Set 6 | iquitos
# Processing Record 39 of Set 6 | salalah
# Processing Record 40 of Set 6 | cape canaveral
# Processing Record 41 of Set 6 | scottsbluff
# Processing Record 42 of Set 6 | port hardy
# Processing Record 43 of Set 6 | saint albans
# Processing Record 44 of Set 6 | mugur-aksy
# Processing Record 45 of Set 6 | guhagar
# Processing Record 46 of Set 6 | george
# Processing Record 47 of Set 6 | nerchinskiy zavod
# Processing Record 48 of Set 6 | srednekolymsk
# Processing Record 49 of Set 6 | santa rosa
# Processing Record 50 of Set 6 | college
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | shache
# Processing Record 3 of Set 7 | san andres
# Processing Record 4 of Set 7 | amapa
# Processing Record 5 of Set 7 | stanari
# Processing Record 6 of Set 7 | mayo
# Processing Record 7 of Set 7 | ye
# City not found. Skipping...
# Processing Record 8 of Set 7 | maldonado
# Processing Record 9 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 10 of Set 7 | pontianak
# Processing Record 11 of Set 7 | sinnamary
# Processing Record 12 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 7 | tyukhtet
# Processing Record 14 of Set 7 | bafilo
# Processing Record 15 of Set 7 | jardim
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | lasa
# Processing Record 18 of Set 7 | yatou
# Processing Record 19 of Set 7 | pisco
# Processing Record 20 of Set 7 | grindavik
# Processing Record 21 of Set 7 | sola
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | yining
# Processing Record 24 of Set 7 | concarneau
# Processing Record 25 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 26 of Set 7 | saint anthony
# Processing Record 27 of Set 7 | bosaso
# Processing Record 28 of Set 7 | haines junction
# Processing Record 29 of Set 7 | rapid valley
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | lagos
# Processing Record 32 of Set 7 | quincy
# Processing Record 33 of Set 7 | tucurui
# Processing Record 34 of Set 7 | altay
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | aswan
# Processing Record 37 of Set 7 | kavaratti
# Processing Record 38 of Set 7 | luderitz
# Processing Record 39 of Set 7 | colac
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | luanda
# Processing Record 42 of Set 7 | atar
# Processing Record 43 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 7 | lincoln
# Processing Record 45 of Set 7 | new norfolk
# Processing Record 46 of Set 7 | pilar
# Processing Record 47 of Set 7 | moose factory
# Processing Record 48 of Set 7 | naryan-mar
# Processing Record 49 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 7 | lorengau
# Processing Record 1 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 2 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 8 | moindou
# Processing Record 4 of Set 8 | los llanos de aridane
# Processing Record 5 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 8 | djenne
# Processing Record 7 of Set 8 | nabire
# Processing Record 8 of Set 8 | wunsiedel
# Processing Record 9 of Set 8 | grand gaube
# Processing Record 10 of Set 8 | wajid
# Processing Record 11 of Set 8 | liberia
# Processing Record 12 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 8 | tanete
# Processing Record 14 of Set 8 | ruzhyn
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | mabaruma
# Processing Record 17 of Set 8 | roald
# Processing Record 18 of Set 8 | komsomolskiy
# Processing Record 19 of Set 8 | lingao
# Processing Record 20 of Set 8 | sanmenxia
# Processing Record 21 of Set 8 | vestmannaeyjar
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 8 | barabinsk
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | westport
# Processing Record 27 of Set 8 | kaya
# Processing Record 28 of Set 8 | nouadhibou
# Processing Record 29 of Set 8 | paracuru
# Processing Record 30 of Set 8 | ushtobe
# Processing Record 31 of Set 8 | sesimbra
# Processing Record 32 of Set 8 | marzuq
# Processing Record 33 of Set 8 | mpika
# Processing Record 34 of Set 8 | santiago del estero
# Processing Record 35 of Set 8 | korem
# Processing Record 36 of Set 8 | cedro
# Processing Record 37 of Set 8 | mecca
# Processing Record 38 of Set 8 | labuhan
# Processing Record 39 of Set 8 | castelo do piaui
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | herat
# Processing Record 42 of Set 8 | orlik
# Processing Record 43 of Set 8 | newport
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | sechura
# Processing Record 48 of Set 8 | rupert
# Processing Record 49 of Set 8 | gizo
# Processing Record 50 of Set 8 | veraval
# Processing Record 1 of Set 9 | saravena
# Processing Record 2 of Set 9 | palauig
# Processing Record 3 of Set 9 | hays
# Processing Record 4 of Set 9 | dongsheng
# Processing Record 5 of Set 9 | kaminokawa
# Processing Record 6 of Set 9 | saurimo
# Processing Record 7 of Set 9 | saint-pierre
# Processing Record 8 of Set 9 | garoua
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | abonnema
# Processing Record 11 of Set 9 | ahipara
# Processing Record 12 of Set 9 | huicungo
# Processing Record 13 of Set 9 | jamshedpur
# Processing Record 14 of Set 9 | bayangol
# Processing Record 15 of Set 9 | nuevitas
# Processing Record 16 of Set 9 | port-gentil
# Processing Record 17 of Set 9 | weymouth
# Processing Record 18 of Set 9 | curup
# Processing Record 19 of Set 9 | eyl
# Processing Record 20 of Set 9 | anahuac
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | lamesa
# Processing Record 23 of Set 9 | bay roberts
# Processing Record 24 of Set 9 | puerto del rosario
# Processing Record 25 of Set 9 | laguna
# Processing Record 26 of Set 9 | bilibino
# Processing Record 27 of Set 9 | tamiahua
# Processing Record 28 of Set 9 | dangara
# Processing Record 29 of Set 9 | macau
# Processing Record 30 of Set 9 | ha giang
# Processing Record 31 of Set 9 | namatanai
# Processing Record 32 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | perth
# Processing Record 35 of Set 9 | matay
# Processing Record 36 of Set 9 | emba
# Processing Record 37 of Set 9 | matadi
# Processing Record 38 of Set 9 | mahebourg
# Processing Record 39 of Set 9 | kantabanji
# Processing Record 40 of Set 9 | qeshm
# Processing Record 41 of Set 9 | jacksonville beach
# Processing Record 42 of Set 9 | san policarpo
# Processing Record 43 of Set 9 | ramapuram
# Processing Record 44 of Set 9 | sungai besar
# Processing Record 45 of Set 9 | nyanza
# Processing Record 46 of Set 9 | maumere
# Processing Record 47 of Set 9 | sagay
# Processing Record 48 of Set 9 | abha
# Processing Record 49 of Set 9 | egvekinot
# Processing Record 50 of Set 9 | sabha
# Processing Record 1 of Set 10 | parati
# Processing Record 2 of Set 10 | penzance
# Processing Record 3 of Set 10 | miraflores
# Processing Record 4 of Set 10 | ambanja
# Processing Record 5 of Set 10 | vila franca do campo
# Processing Record 6 of Set 10 | paramonga
# Processing Record 7 of Set 10 | port lincoln
# Processing Record 8 of Set 10 | colquechaca
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | verona
# Processing Record 11 of Set 10 | we
# City not found. Skipping...
# Processing Record 12 of Set 10 | nagapattinam
# Processing Record 13 of Set 10 | buala
# Processing Record 14 of Set 10 | zafra
# Processing Record 15 of Set 10 | katsuura
# Processing Record 16 of Set 10 | nevsehir
# Processing Record 17 of Set 10 | mogadishu
# Processing Record 18 of Set 10 | marystown
# Processing Record 19 of Set 10 | pujehun
# Processing Record 20 of Set 10 | bulgan
# Processing Record 21 of Set 10 | puerto escondido
# Processing Record 22 of Set 10 | urbano santos
# Processing Record 23 of Set 10 | wichian buri
# Processing Record 24 of Set 10 | ulety
# Processing Record 25 of Set 10 | nytva
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | lewisporte
# Processing Record 29 of Set 10 | bandarbeyla
# Processing Record 30 of Set 10 | salvador
# Processing Record 31 of Set 10 | samarkand
# Processing Record 32 of Set 10 | havoysund
# Processing Record 33 of Set 10 | shelburne
# Processing Record 34 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 10 | kemecse
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | teya
# Processing Record 38 of Set 10 | ola
# Processing Record 39 of Set 10 | halifax
# Processing Record 40 of Set 10 | huarmey
# Processing Record 41 of Set 10 | georgiyevka
# Processing Record 42 of Set 10 | hit
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | oriximina
# Processing Record 45 of Set 10 | salekhard
# Processing Record 46 of Set 10 | rawson
# Processing Record 47 of Set 10 | honiara
# Processing Record 48 of Set 10 | avera
# Processing Record 49 of Set 10 | dutlwe
# Processing Record 50 of Set 10 | cieza
# Processing Record 1 of Set 11 | amuntai
# Processing Record 2 of Set 11 | ano poroia
# Processing Record 3 of Set 11 | mgandu
# Processing Record 4 of Set 11 | urumqi
# Processing Record 5 of Set 11 | tricase
# Processing Record 6 of Set 11 | lata
# Processing Record 7 of Set 11 | abnub
# Processing Record 8 of Set 11 | nelson bay
# Processing Record 9 of Set 11 | maragogi
# Processing Record 10 of Set 11 | zhezkazgan
# Processing Record 11 of Set 11 | fuerte olimpo
# Processing Record 12 of Set 11 | henties bay
# Processing Record 13 of Set 11 | lappeenranta
# Processing Record 14 of Set 11 | auki
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | coquimbo
# Processing Record 17 of Set 11 | tilichiki
# Processing Record 18 of Set 11 | naron
# Processing Record 19 of Set 11 | urdoma
# Processing Record 20 of Set 11 | faanui
# Processing Record 21 of Set 11 | shanhetun
# Processing Record 22 of Set 11 | manado
# Processing Record 23 of Set 11 | gogrial
# Processing Record 24 of Set 11 | coffs harbour
# Processing Record 25 of Set 11 | jalu
# Processing Record 26 of Set 11 | sfantu gheorghe
# Processing Record 27 of Set 11 | cayenne
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | stephenville
# Processing Record 30 of Set 11 | alice springs
# Processing Record 31 of Set 11 | alekseyevsk
# Processing Record 32 of Set 11 | bermeo
# Processing Record 33 of Set 11 | xai-xai
# Processing Record 34 of Set 11 | villa del rosario
# Processing Record 35 of Set 11 | benghazi
# Processing Record 36 of Set 11 | pangoa
# Processing Record 37 of Set 11 | westlock
# Processing Record 38 of Set 11 | makrikapa
# City not found. Skipping...
# Processing Record 39 of Set 11 | tsabong
# Processing Record 40 of Set 11 | lethem
# Processing Record 41 of Set 11 | southampton
# Processing Record 42 of Set 11 | leningradskiy
# Processing Record 43 of Set 11 | arawa
# Processing Record 44 of Set 11 | vostok
# Processing Record 45 of Set 11 | port-cartier
# Processing Record 46 of Set 11 | broome
# Processing Record 47 of Set 11 | kununurra
# Processing Record 48 of Set 11 | gemena
# Processing Record 49 of Set 11 | calvia
# Processing Record 50 of Set 11 | meulaboh
# Processing Record 1 of Set 12 | srivardhan
# Processing Record 2 of Set 12 | magadan
# Processing Record 3 of Set 12 | progreso
# Processing Record 4 of Set 12 | evanston
# Processing Record 5 of Set 12 | palermo
# Processing Record 6 of Set 12 | saraland
# Processing Record 7 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 8 of Set 12 | rio gallegos
# Processing Record 9 of Set 12 | ponta delgada
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | ahuimanu
# Processing Record 12 of Set 12 | cananeia
# Processing Record 13 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 12 | juneau
# Processing Record 15 of Set 12 | kathmandu
# Processing Record 16 of Set 12 | langxiang
# Processing Record 17 of Set 12 | porto novo
# Processing Record 18 of Set 12 | kismayo
# Processing Record 19 of Set 12 | sibu
# Processing Record 20 of Set 12 | chincha alta
# Processing Record 21 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 12 | puerto suarez
# Processing Record 23 of Set 12 | road town
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | jizan
# Processing Record 26 of Set 12 | verkhnyaya inta
# Processing Record 27 of Set 12 | saint-georges
# Processing Record 28 of Set 12 | denpasar
# Processing Record 29 of Set 12 | usogorsk
# Processing Record 30 of Set 12 | piranhas
# Processing Record 31 of Set 12 | san cristobal
# Processing Record 32 of Set 12 | narsaq
# Processing Record 33 of Set 12 | kushima
# Processing Record 34 of Set 12 | taihe
# Processing Record 35 of Set 12 | bassila
# Processing Record 36 of Set 12 | shimonoseki
# Processing Record 37 of Set 12 | port macquarie
# Processing Record 38 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | khomutovka
# Processing Record 40 of Set 12 | timbiqui
# Processing Record 41 of Set 12 | abu dhabi
# Processing Record 42 of Set 12 | ostrovnoy
# Processing Record 43 of Set 12 | caravelas
# Processing Record 44 of Set 12 | krasnoselkup
# Processing Record 45 of Set 12 | mapiripan
# Processing Record 46 of Set 12 | port pirie
# Processing Record 47 of Set 12 | ulaangom
# Processing Record 48 of Set 12 | gisborne
# Processing Record 49 of Set 12 | chicama
# Processing Record 50 of Set 12 | pecos
# Processing Record 1 of Set 13 | inhambane
# Processing Record 2 of Set 13 | sorland
# Processing Record 3 of Set 13 | grand-santi
# Processing Record 4 of Set 13 | villaviciosa
# Processing Record 5 of Set 13 | waitati
# Processing Record 6 of Set 13 | krasnokamensk
# Processing Record 7 of Set 13 | redmond
# Processing Record 8 of Set 13 | kikwit
# Processing Record 9 of Set 13 | vanavara
# Processing Record 10 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 11 of Set 13 | guelavia
# City not found. Skipping...
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | chihuahua
# Processing Record 14 of Set 13 | matagami
# Processing Record 15 of Set 13 | bolobo
# Processing Record 16 of Set 13 | launceston
# Processing Record 17 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 13 | tungor
# Processing Record 20 of Set 13 | lokosovo
# Processing Record 21 of Set 13 | okha
# Processing Record 22 of Set 13 | rohnert park
# Processing Record 23 of Set 13 | krasnoye
# Processing Record 24 of Set 13 | erenhot
# Processing Record 25 of Set 13 | wamba
# Processing Record 26 of Set 13 | sandviken
# Processing Record 27 of Set 13 | half moon bay
# Processing Record 28 of Set 13 | marsabit
# Processing Record 29 of Set 13 | kaduqli
# Processing Record 30 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 31 of Set 13 | rumonge
# Processing Record 32 of Set 13 | cuyo
# Processing Record 33 of Set 13 | alta floresta
# Processing Record 34 of Set 13 | amga
# Processing Record 35 of Set 13 | calama
# Processing Record 36 of Set 13 | yei
# Processing Record 37 of Set 13 | luoyang
# Processing Record 38 of Set 13 | santa cruz de tenerife
# Processing Record 39 of Set 13 | freeport
# Processing Record 40 of Set 13 | brae
# Processing Record 41 of Set 13 | san pedro
# Processing Record 42 of Set 13 | tongliao
# Processing Record 43 of Set 13 | rovaniemi
# Processing Record 44 of Set 13 | fernley
# Processing Record 45 of Set 13 | saint-francois
# Processing Record 46 of Set 13 | tahta
# Processing Record 47 of Set 13 | sept-iles
# Processing Record 48 of Set 13 | padang
# Processing Record 49 of Set 13 | kronshagen
# Processing Record 50 of Set 13 | nyurba
# Processing Record 1 of Set 14 | hommelvik
# Processing Record 2 of Set 14 | quetigny
# Processing Record 3 of Set 14 | jinchang
# Processing Record 4 of Set 14 | semirom
# Processing Record 5 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 14 | tumbes
# Processing Record 7 of Set 14 | guerrero negro
# Processing Record 8 of Set 14 | oistins
# Processing Record 9 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 14 | nabinagar
# Processing Record 11 of Set 14 | kruisfontein
# Processing Record 12 of Set 14 | rafai
# Processing Record 13 of Set 14 | yarensk
# Processing Record 14 of Set 14 | wageningen
# Processing Record 15 of Set 14 | mangai
# Processing Record 16 of Set 14 | petukhovo
# Processing Record 17 of Set 14 | taltal
# Processing Record 18 of Set 14 | guarapari
# Processing Record 19 of Set 14 | poltavka
# Processing Record 20 of Set 14 | hudson bay
# Processing Record 21 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 14 | korla
# Processing Record 23 of Set 14 | saldanha
# Processing Record 24 of Set 14 | vanimo
# Processing Record 25 of Set 14 | chara
# Processing Record 26 of Set 14 | moron de la frontera
# Processing Record 27 of Set 14 | jiaojiang
# Processing Record 28 of Set 14 | iglesias
# Processing Record 29 of Set 14 | aquiraz
# Processing Record 30 of Set 14 | trairi
# Processing Record 31 of Set 14 | sakakah
# Processing Record 32 of Set 14 | chekhov
# Processing Record 33 of Set 14 | cimarron hills
# Processing Record 34 of Set 14 | bendigo
# Processing Record 35 of Set 14 | zvishavane
# Processing Record 36 of Set 14 | ingham
# Processing Record 37 of Set 14 | micheweni
# Processing Record 38 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 14 | piterka
# Processing Record 40 of Set 14 | luganville
# Processing Record 41 of Set 14 | conceicao do araguaia
# Processing Record 42 of Set 14 | yanam
# Processing Record 43 of Set 14 | itaquyry
# Processing Record 44 of Set 14 | baijiantan
# Processing Record 45 of Set 14 | cruzilia
# Processing Record 46 of Set 14 | severomuysk
# Processing Record 47 of Set 14 | loandjili
# Processing Record 48 of Set 14 | kapit
# Processing Record 49 of Set 14 | mehran
# Processing Record 50 of Set 14 | cartagena del chaira
# Processing Record 1 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 15 | puerto ayacucho
# Processing Record 3 of Set 15 | hamilton
# Processing Record 4 of Set 15 | buritis
# Processing Record 5 of Set 15 | moba
# Processing Record 6 of Set 15 | kaliyaganj
# Processing Record 7 of Set 15 | rio bananal
# Processing Record 8 of Set 15 | keffi
# Processing Record 9 of Set 15 | arona
# Processing Record 10 of Set 15 | newberry
# Processing Record 11 of Set 15 | quatre cocos
# Processing Record 12 of Set 15 | price
# Processing Record 13 of Set 15 | pangnirtung
# Processing Record 14 of Set 15 | lexington
# Processing Record 15 of Set 15 | san matias
# Processing Record 16 of Set 15 | donegal
# Processing Record 17 of Set 15 | bambanglipuro
# Processing Record 18 of Set 15 | tahoua
# Processing Record 19 of Set 15 | bowen
# Processing Record 20 of Set 15 | elko
# Processing Record 21 of Set 15 | plotnikovo
# Processing Record 22 of Set 15 | hay river
# Processing Record 23 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 15 | mushie
# Processing Record 25 of Set 15 | chifeng
# Processing Record 26 of Set 15 | leshukonskoye
# Processing Record 27 of Set 15 | constitucion
# Processing Record 28 of Set 15 | grimshaw
# Processing Record 29 of Set 15 | campos belos
# Processing Record 30 of Set 15 | tual
# Processing Record 31 of Set 15 | povenets
# Processing Record 32 of Set 15 | kropotkin
# Processing Record 33 of Set 15 | dargaville
# Processing Record 34 of Set 15 | saint-augustin
# Processing Record 35 of Set 15 | san quintin
# Processing Record 36 of Set 15 | pampa
# Processing Record 37 of Set 15 | smolenka
# Processing Record 38 of Set 15 | imbituba
# Processing Record 39 of Set 15 | marovoay
# Processing Record 40 of Set 15 | portland
# Processing Record 41 of Set 15 | akdepe
# Processing Record 42 of Set 15 | porto empedocle
# Processing Record 43 of Set 15 | gushikawa
# Processing Record 44 of Set 15 | humen
# Processing Record 45 of Set 15 | pumiao
# Processing Record 46 of Set 15 | tiznit
# Processing Record 47 of Set 15 | pimentel
# Processing Record 48 of Set 15 | aklavik
# Processing Record 49 of Set 15 | ourinhos
# Processing Record 50 of Set 15 | kishi
# Processing Record 1 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 16 | svetlaya
# Processing Record 3 of Set 16 | lewistown
# Processing Record 4 of Set 16 | fort saint james
# Processing Record 5 of Set 16 | fukue
# Processing Record 6 of Set 16 | petropavlovka
# Processing Record 7 of Set 16 | kathu
# Processing Record 8 of Set 16 | panaba
# Processing Record 9 of Set 16 | kralendijk
# Processing Record 10 of Set 16 | manzhouli
# Processing Record 11 of Set 16 | san vicente
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Gornopravdinsk  60.0500   69.9000     44.29        86          86
# 1              Morro Bay  35.3658 -120.8499     68.40        88          38
# 2           Punta Arenas -53.1500  -70.9167     44.71        70          75
# 3               Thompson  55.7435  -97.8558     28.56        86          20
# 4             Nikolskoye  59.7035   30.7861     48.09        94         100
# 5                Rikitea -23.1203 -134.9692     71.08        71          23
# 6                Lyngdal  58.1376    7.0700     51.89        82         100
# 7  Mayor Pablo Lagerenza -19.9309  -60.7718     82.15        47          71
# 8                  Kapaa  22.0752 -159.3190     80.92        70           0
# 9              Carnarvon -24.8667  113.6333     73.38        48          30
#
#    Wind Speed Country Current Description
# 0        5.91      RU     overcast clouds
# 1        3.36      US    scattered clouds
# 2       37.98      CL          light rain
# 3        2.30      CA          few clouds
# 4        6.98      RU     overcast clouds
# 5       19.77      PF          light rain
# 6       10.92      NO     overcast clouds
# 7        4.00      PY       broken clouds
# 8        9.22      US           clear sky
# 9       14.99      AU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
reordered_city_data_df = city_data_df[new_column_order]

# Display sample data
reordered_city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Gornopravdinsk      RU  60.0500   69.9000     44.29        86
# 1              Morro Bay      US  35.3658 -120.8499     68.40        88
# 2           Punta Arenas      CL -53.1500  -70.9167     44.71        70
# 3               Thompson      CA  55.7435  -97.8558     28.56        86
# 4             Nikolskoye      RU  59.7035   30.7861     48.09        94
# 5                Rikitea      PF -23.1203 -134.9692     71.08        71
# 6                Lyngdal      NO  58.1376    7.0700     51.89        82
# 7  Mayor Pablo Lagerenza      PY -19.9309  -60.7718     82.15        47
# 8                  Kapaa      US  22.0752 -159.3190     80.92        70
# 9              Carnarvon      AU -24.8667  113.6333     73.38        48
#
#    Cloudiness  Wind Speed Current Description
# 0          86        5.91     overcast clouds
# 1          38        3.36    scattered clouds
# 2          75       37.98          light rain
# 3          20        2.30          few clouds
# 4         100        6.98     overcast clouds
# 5          23       19.77          light rain
# 6         100       10.92     overcast clouds
# 7          71        4.00       broken clouds
# 8           0        9.22           clear sky
# 9          30       14.99    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
reordered_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
reordered_city_data_df.to_csv(output_data_file, index_label="City_ID")
